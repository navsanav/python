# %%
import pandas as pd
import numpy as np

# %%
dict={
    "name":['rahul','sandeep','himanshu'],
    "age":[25,27,24],
    "city":["jaipur","delhi","manpura"]
}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#        name  age     city
# 0     rahul   25   jaipur
# 1   sandeep   27    delhi
# 2  himanshu   24  manpura

# %%
df.to_csv("friends.csv")

# %%
pd.read_csv("friends.csv")
# Out:
#    Unnamed: 0      name  age     city
# 0           0     rahul   25   jaipur
# 1           1   sandeep   27    delhi
# 2           2  himanshu   24  manpura

# %%
df.to_csv("friends_index_false.csv",index=False)

# %%
df.head(1)
# Out:
#     name  age    city
# 0  rahul   25  jaipur

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   25.333333
# std     1.527525
# min    24.000000
# 25%    24.500000
# 50%    25.000000
# 75%    26.000000
# max    27.000000

# %%
sandeep=pd.read_csv("sandeep.csv")

# %%
sandeep
# Out:
#     Unnamed: 0  train name  speed       city   time  charges  distance
# 0            0       23344     25     jaipur  12:00      100        50
# 1            1      233223     27      delhi  13:00      200       100
# 2            2       23455     24    manpura  14:00      300       200
# 3            3        6556     23    jodhpur  15:00      400       300
# 4            4         454     33    bikaner  16:00      500       400
# 5            5        5435     44        raj  17:00      600       500
# 6            6       45677     66    sitaram  18:00      700       600
# 7            7       43526     66  jaisamand  19:00      800       700
# 8            8      236773     67   udiaypur  20:00      900       800
# 9            9      352627     55       kota  21:00     1000       900
# 10          10        4533     78     kerala  22:00     1100      1000
# 11          11      363738     66    chennai  23:00     1200      1100
# ...

# %%
sandeep.head(5)
# Out:
#    Unnamed: 0  train name  speed     city   time  charges  distance
# 0           0       23344     25   jaipur  12:00      100        50
# 1           1      233223     27    delhi  13:00      200       100
# 2           2       23455     24  manpura  14:00      300       200
# 3           3        6556     23  jodhpur  15:00      400       300
# 4           4         454     33  bikaner  16:00      500       400

# %%
sandeep["speed"][0]=20
# Out:
# C:\Users\mss2015\AppData\Local\Temp\ipykernel_6216\1444748435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sandeep["speed"][0]=20

# %%
sandeep
# Out:
#     Unnamed: 0  train name  speed       city   time  charges  distance
# 0            0       23344     20     jaipur  12:00      100        50
# 1            1      233223     27      delhi  13:00      200       100
# 2            2       23455     24    manpura  14:00      300       200
# 3            3        6556     23    jodhpur  15:00      400       300
# 4            4         454     33    bikaner  16:00      500       400
# 5            5        5435     44        raj  17:00      600       500
# 6            6       45677     66    sitaram  18:00      700       600
# 7            7       43526     66  jaisamand  19:00      800       700
# 8            8      236773     67   udiaypur  20:00      900       800
# 9            9      352627     55       kota  21:00     1000       900
# 10          10        4533     78     kerala  22:00     1100      1000
# 11          11      363738     66    chennai  23:00     1200      1100
# ...

# %%
sandeep.to_csv('sandy1.csv')

# %%
sandy1=pd.read_csv("sandy1.csv")

# %%
sandy1
# Out:
#     Unnamed: 0.1  Unnamed: 0  train name  speed       city   time  charges  \
# 0              0           0       23344     20     jaipur  12:00      100
# 1              1           1      233223     27      delhi  13:00      200
# 2              2           2       23455     24    manpura  14:00      300
# 3              3           3        6556     23    jodhpur  15:00      400
# 4              4           4         454     33    bikaner  16:00      500
# 5              5           5        5435     44        raj  17:00      600
# 6              6           6       45677     66    sitaram  18:00      700
# 7              7           7       43526     66  jaisamand  19:00      800
# 8              8           8      236773     67   udiaypur  20:00      900
# 9              9           9      352627     55       kota  21:00     1000
# 10            10          10        4533     78     kerala  22:00     1100
# ...

# %%
sandy1.index = ['a','b','c','d','e','f','g','h','i','j','k','l','m']

# %%
sandy1
# Out:
#    Unnamed: 0.1  Unnamed: 0  train name  speed       city   time  charges  \
# a             0           0       23344     20     jaipur  12:00      100
# b             1           1      233223     27      delhi  13:00      200
# c             2           2       23455     24    manpura  14:00      300
# d             3           3        6556     23    jodhpur  15:00      400
# e             4           4         454     33    bikaner  16:00      500
# f             5           5        5435     44        raj  17:00      600
# g             6           6       45677     66    sitaram  18:00      700
# h             7           7       43526     66  jaisamand  19:00      800
# i             8           8      236773     67   udiaypur  20:00      900
# j             9           9      352627     55       kota  21:00     1000
# k            10          10        4533     78     kerala  22:00     1100
# l            11          11      363738     66    chennai  23:00     1200
# ...

# %%
sandy1.to_csv('sandy1.csv')
