# %%
class Phone:
    def set_clr(self,clr="blue"):
        self.clr=clr
    def show_clr(self):
        return self.clr
    def
p1=Phone()
p1.show_clr()
# Out:
# 'kjd'

# %%
p1.show_clr()
# Out:
# 'kjd'
